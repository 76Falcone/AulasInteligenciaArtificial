# %% [markdown]
# Exercicio 1 - Escrever uma mensagem no terminal

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Exercicio 2 - Somar 2 numeros
#
# ---
# Somente perdimito digitar numeros no padrão americano, sem virgulas

# %%
n1 = float(input("Digite o primeiro numero: "))
n2 = float(input("Digite o segundo numero: "))
soma = n1 + n2
print("A soma dos numeros é: ", soma)
# Out:
# Digite o primeiro numero: 10.2
# Digite o segundo numero: 18.7
# A soma dos numeros é:  28.9
